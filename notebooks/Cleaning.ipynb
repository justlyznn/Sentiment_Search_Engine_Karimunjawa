# %%
import pandas as pd
import re

# %%
df = pd.read_csv("../data/raw/dataset_Google-Maps-Reviews-Scraper_Pantai.csv")
df.head()
# Out:
#                   title                                                url  \
# 0  Pantai Tanjung Gelam  https://www.google.com/maps/search/?api=1&quer...
# 1  Pantai Tanjung Gelam  https://www.google.com/maps/search/?api=1&quer...
# 2  Pantai Tanjung Gelam  https://www.google.com/maps/search/?api=1&quer...
# 3  Pantai Tanjung Gelam  https://www.google.com/maps/search/?api=1&quer...
# 4  Pantai Tanjung Gelam  https://www.google.com/maps/search/?api=1&quer...
#
#    stars             name                                          reviewUrl  \
# 0      5         araso mu  https://www.google.com/maps/reviews/data=!4m8!...
# 1      5     ARIAN BAWANA  https://www.google.com/maps/reviews/data=!4m8!...
# 2      5   Desis Triyasih  https://www.google.com/maps/reviews/data=!4m8!...
# 3      5     rizal taufik  https://www.google.com/maps/reviews/data=!4m8!...
# 4      5  Iwan Kristianto  https://www.google.com/maps/reviews/data=!4m8!...
#
# ...

# %%
df = df[['title', 'stars', 'text']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1082 entries, 0 to 1081
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1082 non-null   object
#  1   stars   1082 non-null   int64
#  2   text    731 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 25.5+ KB

# %%
df['text'] = df['text'].astype(str).str.lower()
df['text'] = df['text'].replace('false', pd.NA)
df = df.dropna(subset=['text'])
df = df[df['text'] != 'false']

# %%
df = df.drop_duplicates(subset=['text'])

# %%
df = df.dropna()

# %%
def clean_gmaps_text(text):
    text = re.sub(r"@[A-Za-z0-9]+", '', text)
    text = re.sub(r"#\w+", '', text)
    text = re.sub(r"RT[\s]+", '', text)
    text = re.sub(r"https?://\S+", '', text)
    text = re.sub(r"[^A-Za-z0-9 ]", '', text)
    text = re.sub(r"\s+", ' ', text).strip()

    return text

df['text'] = df['text'].apply(clean_gmaps_text)

# %%
df.head()
# Out:
#                   title  stars  \
# 0  Pantai Tanjung Gelam      5
# 2  Pantai Tanjung Gelam      5
# 3  Pantai Tanjung Gelam      5
# 4  Pantai Tanjung Gelam      5
# 5  Pantai Tanjung Gelam      5
#
#                                                 text
# 0                                                nan
# 2  pantai yang menakjubkan dengan pasirpasir puti...
# 3  pantai tanjung gelam merupakan salah satu pant...
# 4  salah satu pantai favorit bila ke karimunjawa ...
# 5  pantai denganpasir putih yang bersih panorama ...

# %%
df.to_csv('../data/cleaning/clear_data.csv', index=False)
